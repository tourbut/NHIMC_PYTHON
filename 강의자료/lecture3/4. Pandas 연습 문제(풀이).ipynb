# %%
import pandas as pd

# %%
sample = pd.read_csv("내국인 생활인구.csv", encoding="cp949")
sample.head(1)
# Out:
#    일자(stdr_de_id)  시간(tmzon_pd_se)  행정동코드(adstrd_code_se)   집계구코드(oa_cd)  \
# 0        20170226                4               11320515  1125061020007
#
#    생활인구합계(tot_lvpop_co)  남자0~9세(male_f0t9_lvpop_co)  \
# 0                4.3097                     11.9781
#
#    남자10~14세(male_f10t14_lvpop_co)  남자15~19세(male_f15t19_lvpop_co)  \
# 0                          8.2257                          1.8759
#
#    남자20~24세(male_f20t24_lvpop_co)  남자25~29세(male_f25t29_lvpop_co)  ...  \
# 0                          4.2075                          6.2647  ...
#
#    여자40~44세(female_f40t44_lvpop_co)  여자45~49세(female_f45t49_lvpop_co)  \
# 0                            9.0816                           52.6711
#
#    여자50~54세(female_f50t54_lvpop_co)  여자55~59세(female_f55t59_lvpop_co)  \
# 0                           24.9152                            3.6202
#
#    여자60~64세(female_f60t64_lvpop_co)  여자65~69세(female_f65t69_lvpop_co)  \
# ...

# %% [markdown]
# ## 1. 컬럼명 바꾸기
#
# sample에 있는 컬럼명에서 한글 컬럼명만 남겨주세요.
# 예시: `일자(stdr_de_id)` -> `일자`

# %%
#컬럼 확인
sample.columns
# Out:
# Index(['일자(stdr_de_id)', '시간(tmzon_pd_se)', '행정동코드(adstrd_code_se)',
#        '집계구코드(oa_cd)', '생활인구합계(tot_lvpop_co)', '남자0~9세(male_f0t9_lvpop_co)',
#        '남자10~14세(male_f10t14_lvpop_co)', '남자15~19세(male_f15t19_lvpop_co)',
#        '남자20~24세(male_f20t24_lvpop_co)', '남자25~29세(male_f25t29_lvpop_co)',
#        '남자30~34세(male_f30t34_lvpop_co)', '남자35~39세(male_f35t39_lvpop_co)',
#        '남자40~44세(male_f40t44_lvpop_co)', '남자45~49세(male_f45t49_lvpop_co)',
#        '남자50~54세(male_f50t54_lvpop_co)', '남자55~59세(male_f55t59_lvpop_co)',
#        '남자60~64세(male_f60t64_lvpop_co)', '남자65~69세(male_f65t69_lvpop_co)',
#        '남자70~74세(male_f70t74_lvpop_co)', '남자75~79세(male_f75t79_lvpop_co)',
#        '남자80세이상(male_above_80_lvpop_co)', '여자0~9세(female_f0t9_lvpop_co)',
#        '여자10~14세(female_f10t14_lvpop_co)', '여자15~19세(female_f15t19_lvpop_co)',
#        '여자20~24세(female_f20t24_lvpop_co)', '여자25~29세(female_f25t29_lvpop_co)',
# ...

# %%
sample.columns[0].split("(")[0]
# Out:
# '일자'

# %%
new_columns = []
for col in sample.columns:
    new_columns.append(col.split("(")[0])

# %%
print(new_columns)
# Out:
# ['일자', '시간', '행정동코드', '집계구코드', '생활인구합계', '남자0~9세', '남자10~14세', '남자15~19세', '남자20~24세', '남자25~29세', '남자30~34세', '남자35~39세', '남자40~44세', '남자45~49세', '남자50~54세', '남자55~59세', '남자60~64세', '남자65~69세', '남자70~74세', '남자75~79세', '남자80세이상', '여자0~9세', '여자10~14세', '여자15~19세', '여자20~24세', '여자25~29세', '여자30~34세', '여자35~39세', '여자40~44세', '여자45~49세', '여자50~54세', '여자55~59세', '여자60~64세', '여자65~69세', '여자70~74세', '여자75~79세', '여자80세이상', '등록일자']

# %%
#답변 작성
sample.columns = new_columns

# %%
sample.columns
# Out:
# Index(['일자', '시간', '행정동코드', '집계구코드', '생활인구합계', '남자0~9세', '남자10~14세',
#        '남자15~19세', '남자20~24세', '남자25~29세', '남자30~34세', '남자35~39세', '남자40~44세',
#        '남자45~49세', '남자50~54세', '남자55~59세', '남자60~64세', '남자65~69세', '남자70~74세',
#        '남자75~79세', '남자80세이상', '여자0~9세', '여자10~14세', '여자15~19세', '여자20~24세',
#        '여자25~29세', '여자30~34세', '여자35~39세', '여자40~44세', '여자45~49세', '여자50~54세',
#        '여자55~59세', '여자60~64세', '여자65~69세', '여자70~74세', '여자75~79세', '여자80세이상',
#        '등록일자'],
#       dtype='object')

# %% [markdown]
# ## 2. 인덱스 설정
# `일자` 컬럼을 인덱스로 설정해주세요.

# %% [markdown]
# 일자 인덱스를 datetime 형식으로 변경한 뒤, 날짜 오름차 순으로 데이터를 정렬할 것입니다.
# astype() 메서드를 사용해서 sample.index를 str형으로 바꿔주세요.
#
# 참고) https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.astype.html

# %%
#일자 컬럼 타입 확인
sample.dtypes
# Out:
# 일자            int64
# 시간            int64
# 행정동코드         int64
# 집계구코드         int64
# 생활인구합계      float64
# 남자0~9세      float64
# 남자10~14세    float64
# 남자15~19세    float64
# 남자20~24세    float64
# 남자25~29세    float64
# 남자30~34세    float64
# 남자35~39세    float64
# 남자40~44세    float64
# 남자45~49세    float64
# 남자50~54세    float64
# 남자55~59세    float64
# 남자60~64세    float64
# 남자65~69세    float64
# 남자70~74세    float64
# 남자75~79세    float64
# 남자80세이상     float64
# 여자0~9세      float64
# 여자10~14세    float64
# 여자15~19세    float64
# 여자20~24세    float64
# 여자25~29세    float64
# 여자30~34세    float64
# 여자35~39세    float64
# 여자40~44세    float64
# 여자45~49세    float64
# 여자50~54세    float64
# 여자55~59세    float64
# 여자60~64세    float64
# 여자65~69세    float64
# 여자70~74세    float64
# 여자75~79세    float64
# 여자80세이상     float64
# 등록일자         object
# dtype: object

# %%
sample['일자'] = sample['일자'].astype("str")

# %% [markdown]
# str로 변경된 인덱스를 pd.to_datetime 메서드를 사용하여 datetime 형식으로 바꿔주세요.
#
# 참고) https://pandas.pydata.org/docs/reference/api/pandas.to_datetime.html

# %%
#답변 작성
sample['일자'] = pd.to_datetime(sample['일자'])

# %%
#확인
sample.dtypes
# Out:
# 일자          datetime64[ns]
# 시간                   int64
# 행정동코드                int64
# 집계구코드                int64
# 생활인구합계             float64
# 남자0~9세             float64
# 남자10~14세           float64
# 남자15~19세           float64
# 남자20~24세           float64
# 남자25~29세           float64
# 남자30~34세           float64
# 남자35~39세           float64
# 남자40~44세           float64
# 남자45~49세           float64
# 남자50~54세           float64
# 남자55~59세           float64
# 남자60~64세           float64
# 남자65~69세           float64
# 남자70~74세           float64
# 남자75~79세           float64
# 남자80세이상            float64
# 여자0~9세             float64
# 여자10~14세           float64
# 여자15~19세           float64
# 여자20~24세           float64
# 여자25~29세           float64
# 여자30~34세           float64
# 여자35~39세           float64
# 여자40~44세           float64
# 여자45~49세           float64
# 여자50~54세           float64
# 여자55~59세           float64
# 여자60~64세           float64
# 여자65~69세           float64
# ...

# %%
#답변 작성
sample = sample.set_index("일자")

# %% [markdown]
# sort_index() 메서드를 사용하여 주어진 데이터를 인덱스 날짜 오름차 순으로 정렬해주세요.
#
# 참고) https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.sort_index.html

# %%
#답변 작성
sample = sample.sort_index(ascending=True)

# %%
sample
# Out:
#             시간     행정동코드          집계구코드    생활인구합계   남자0~9세  남자10~14세  \
# 일자
# 2017-01-03  15  11305606  1104054010701  381.3905  17.0115   92.1554
# 2017-01-10   9  11620745  1116074030413  217.1740  34.4247    4.5680
# 2017-01-12   8  11230545  1120073020201  183.6538  64.1677   16.6423
# 2017-01-13  13  11620725  1120053020501  173.0124   6.0142   13.9943
# 2017-01-14  13  11215850  1121064020010    3.2861   0.8931    0.0000
# ...         ..       ...            ...       ...      ...       ...
# 2021-10-14  10  11215847  1125065020001  635.4962   1.5913    3.8215
# 2021-10-18   1  11740660  1110055020202    0.7767   7.7059    0.4624
# 2021-10-18   0  11545630  1103072010002  560.6100   4.8471    1.5185
# 2021-10-19  23  11410690  1111056060805  202.2415  14.1716    8.1867
# 2021-10-21  21  11650530  1108072030003  111.6846  18.2460    1.6217
#
#             남자15~19세  남자20~24세  남자25~29세  남자30~34세  ...  여자40~44세  여자45~49세  \
# ...

# %% [markdown]
# ## 3. 조건에 맞는 데이터 추출
# 집계구 코드가 `1107073040015` 또는 `1113073020101`인 행을 뽑아주세요.

# %%
sample['집계구코드'].isin([1107073040015,1113073020101])
# Out:
# 일자
# 2017-01-03    False
# 2017-01-10    False
# 2017-01-12    False
# 2017-01-13    False
# 2017-01-14    False
#               ...
# 2021-10-14    False
# 2021-10-18    False
# 2021-10-18    False
# 2021-10-19    False
# 2021-10-21    False
# Name: 집계구코드, Length: 500, dtype: bool

# %%
sample
# Out:
#             시간     행정동코드          집계구코드    생활인구합계   남자0~9세  남자10~14세  \
# 일자
# 2017-01-03  15  11305606  1104054010701  381.3905  17.0115   92.1554
# 2017-01-10   9  11620745  1116074030413  217.1740  34.4247    4.5680
# 2017-01-12   8  11230545  1120073020201  183.6538  64.1677   16.6423
# 2017-01-13  13  11620725  1120053020501  173.0124   6.0142   13.9943
# 2017-01-14  13  11215850  1121064020010    3.2861   0.8931    0.0000
# ...         ..       ...            ...       ...      ...       ...
# 2021-10-14  10  11215847  1125065020001  635.4962   1.5913    3.8215
# 2021-10-18   1  11740660  1110055020202    0.7767   7.7059    0.4624
# 2021-10-18   0  11545630  1103072010002  560.6100   4.8471    1.5185
# 2021-10-19  23  11410690  1111056060805  202.2415  14.1716    8.1867
# 2021-10-21  21  11650530  1108072030003  111.6846  18.2460    1.6217
#
#             남자15~19세  남자20~24세  남자25~29세  남자30~34세  ...  여자40~44세  여자45~49세  \
# ...

# %%
sample[['행정동코드','집계구코드']]
# Out:
#                행정동코드          집계구코드
# 일자
# 2017-01-03  11305606  1104054010701
# 2017-01-10  11620745  1116074030413
# 2017-01-12  11230545  1120073020201
# 2017-01-13  11620725  1120053020501
# 2017-01-14  11215850  1121064020010
# ...              ...            ...
# 2021-10-14  11215847  1125065020001
# 2021-10-18  11740660  1110055020202
# 2021-10-18  11545630  1103072010002
# 2021-10-19  11410690  1111056060805
# 2021-10-21  11650530  1108072030003
#
# [500 rows x 2 columns]

# %%
#답변 작성
condition = (sample['집계구코드'].isin([1107073040015,1113073020101]))
#condition = (sample['집계구코드'] == 1107073040015) | (sample['집계구코드'] == 1113073020101)
sample.loc[condition]
# Out:
#             시간     행정동코드          집계구코드     생활인구합계  남자0~9세  남자10~14세  \
# 일자
# 2018-03-17   6  11680610  1113073020101  1805.5256  4.3720  324.3596
# 2021-07-06   6  11740660  1107073040015   744.6219  0.5662    2.9824
#
#             남자15~19세  남자20~24세  남자25~29세  남자30~34세  ...  여자40~44세  여자45~49세  \
# 일자                                                  ...
# 2018-03-17   10.8350   12.1324   20.4938    1.2299  ...   28.8794   19.4895
# 2021-07-06    2.9719   31.0868    7.2338  115.6026  ...   39.7471    1.5230
#
#             여자50~54세  여자55~59세  여자60~64세  여자65~69세  여자70~74세  여자75~79세  \
# 일자
# 2018-03-17    1.6087   16.2525    8.1640   34.3989    3.4030    3.8434
# 2021-07-06   47.5514   63.4768   52.3638   35.3496   32.1275   85.6665
#
#             여자80세이상                 등록일자
# 일자
# 2018-03-17   4.4772  2021-08-17 16:06:44
# 2021-07-06  95.0249  2021-08-17 16:06:44
#
# [2 rows x 37 columns]

# %%
#답변 작성
condition = (sample['집계구코드'] == 1107073040015) | (sample['집계구코드'] == 1113073020101)
sample.loc[condition]
# Out:
#             시간     행정동코드          집계구코드     생활인구합계  남자0~9세  남자10~14세  \
# 일자
# 2018-03-17   6  11680610  1113073020101  1805.5256  4.3720  324.3596
# 2021-07-06   6  11740660  1107073040015   744.6219  0.5662    2.9824
#
#             남자15~19세  남자20~24세  남자25~29세  남자30~34세  ...  여자40~44세  여자45~49세  \
# 일자                                                  ...
# 2018-03-17   10.8350   12.1324   20.4938    1.2299  ...   28.8794   19.4895
# 2021-07-06    2.9719   31.0868    7.2338  115.6026  ...   39.7471    1.5230
#
#             여자50~54세  여자55~59세  여자60~64세  여자65~69세  여자70~74세  여자75~79세  \
# 일자
# 2018-03-17    1.6087   16.2525    8.1640   34.3989    3.4030    3.8434
# 2021-07-06   47.5514   63.4768   52.3638   35.3496   32.1275   85.6665
#
#             여자80세이상                 등록일자
# 일자
# 2018-03-17   4.4772  2021-08-17 16:06:44
# 2021-07-06  95.0249  2021-08-17 16:06:44
#
# [2 rows x 37 columns]

# %% [markdown]
# ## 4. apply 활용
#
# 각 행에 대해 남성 인구의 합을 구하여 `남자인구 합계` 이름을 가진 컬럼을 생성해주세요.

# %%
def getManPopulation(row):
    man = 0
    
    for i in row.index:
        if i.startswith("남자"):
            man += row[i]
    
    #답변 작성
            
    return man

sample['남자인구 합계'] = sample.apply(getManPopulation, axis=1)

sample.head()
# Out:
#             시간     행정동코드          집계구코드    생활인구합계   남자0~9세  남자10~14세  \
# 일자
# 2017-01-03  15  11305606  1104054010701  381.3905  17.0115   92.1554
# 2017-01-10   9  11620745  1116074030413  217.1740  34.4247    4.5680
# 2017-01-12   8  11230545  1120073020201  183.6538  64.1677   16.6423
# 2017-01-13  13  11620725  1120053020501  173.0124   6.0142   13.9943
# 2017-01-14  13  11215850  1121064020010    3.2861   0.8931    0.0000
#
#             남자15~19세  남자20~24세  남자25~29세  남자30~34세  ...  여자50~54세  여자55~59세  \
# 일자                                                  ...
# 2017-01-03    7.8037    2.8387   11.4774    3.6876  ...    9.4217    9.4964
# 2017-01-10   10.3187   23.2219   11.2559    6.1775  ...    0.0000    9.6557
# 2017-01-12   13.0121   10.8813   74.4329    4.5769  ...    0.0009   46.9347
# 2017-01-13    5.8550    3.6267   21.3657   46.0382  ...   75.5874    0.0000
# 2017-01-14    0.0000    0.0000   25.7647   26.4582  ...   11.4491    2.1314
#
# ...

# %%
sample.drop('남자인구 합계', axis=1, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# f:\MyGit\My\NHIMC_PYTHON\lecture3\4. Pandas 연습 문제(풀이).ipynb 셀 34 line 1
# ----> <a href='vscode-notebook-cell:/f%3A/MyGit/My/NHIMC_PYTHON/lecture3/4.%20Pandas%20%EC%97%B0%EC%8A%B5%20%EB%AC%B8%EC%A0%9C%28%ED%92%80%EC%9D%B4%29.ipynb#X36sZmlsZQ%3D%3D?line=0'>1</a> sample.drop('남자인구 합계', axis=1, inplace=True)
#
# File f:\MyGit\My\NHIMC_PYTHON\.venv\Lib\site-packages\pandas\core\frame.py:5258, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5110 def drop(
#    5111     self,
#    5112     labels: IndexLabel = None,
#    (...)
#    5119     errors: IgnoreRaise = "raise",
#    5120 ) -> DataFrame | None:
#    5121     """
#    5122     Drop specified labels from rows or columns.
#    5123
#    (...)
#    5256             weight  1.0     0.8
#    5257     """
# -> 5258     return super().drop(
# ...

# %%
남자_컬럼들 = [col for col in sample.columns if '남자' in col]

# %%
남자_컬럼들
# Out:
# ['남자0~9세',
#  '남자10~14세',
#  '남자15~19세',
#  '남자20~24세',
#  '남자25~29세',
#  '남자30~34세',
#  '남자35~39세',
#  '남자40~44세',
#  '남자45~49세',
#  '남자50~54세',
#  '남자55~59세',
#  '남자60~64세',
#  '남자65~69세',
#  '남자70~74세',
#  '남자75~79세',
#  '남자80세이상']

# %%
sample['합계2'] = sample[남자_컬럼들].sum(axis=1)

# %%
sample
# Out:
#             시간     행정동코드          집계구코드    생활인구합계   남자0~9세  남자10~14세  \
# 일자
# 2017-01-03  15  11305606  1104054010701  381.3905  17.0115   92.1554
# 2017-01-10   9  11620745  1116074030413  217.1740  34.4247    4.5680
# 2017-01-12   8  11230545  1120073020201  183.6538  64.1677   16.6423
# 2017-01-13  13  11620725  1120053020501  173.0124   6.0142   13.9943
# 2017-01-14  13  11215850  1121064020010    3.2861   0.8931    0.0000
# ...         ..       ...            ...       ...      ...       ...
# 2021-10-14  10  11215847  1125065020001  635.4962   1.5913    3.8215
# 2021-10-18   1  11740660  1110055020202    0.7767   7.7059    0.4624
# 2021-10-18   0  11545630  1103072010002  560.6100   4.8471    1.5185
# 2021-10-19  23  11410690  1111056060805  202.2415  14.1716    8.1867
# 2021-10-21  21  11650530  1108072030003  111.6846  18.2460    1.6217
#
#             남자15~19세  남자20~24세  남자25~29세  남자30~34세  ...  여자45~49세  여자50~54세  \
# ...

# %% [markdown]
# ## 5. 시각화

# %% [markdown]
# 남성인구 중 남자0\~9세가 차지하는 비율을 계산하여 "남자0~9세 비율" 컬럼을 만들어주세요.

# %%
#답변 작성
sample['남자0~9세 비율'] = sample['남자0~9세'] / sample['남자인구 합계'] * 100

# %%
sample
# Out:
#             시간     행정동코드          집계구코드    생활인구합계   남자0~9세  남자10~14세  \
# 일자
# 2017-01-03  15  11305606  1104054010701  381.3905  17.0115   92.1554
# 2017-01-10   9  11620745  1116074030413  217.1740  34.4247    4.5680
# 2017-01-12   8  11230545  1120073020201  183.6538  64.1677   16.6423
# 2017-01-13  13  11620725  1120053020501  173.0124   6.0142   13.9943
# 2017-01-14  13  11215850  1121064020010    3.2861   0.8931    0.0000
# ...         ..       ...            ...       ...      ...       ...
# 2021-10-14  10  11215847  1125065020001  635.4962   1.5913    3.8215
# 2021-10-18   1  11740660  1110055020202    0.7767   7.7059    0.4624
# 2021-10-18   0  11545630  1103072010002  560.6100   4.8471    1.5185
# 2021-10-19  23  11410690  1111056060805  202.2415  14.1716    8.1867
# 2021-10-21  21  11650530  1108072030003  111.6846  18.2460    1.6217
#
#             남자15~19세  남자20~24세  남자25~29세  남자30~34세  ...  여자55~59세  여자60~64세  \
# ...

# %% [markdown]
# 시간의 흐름에 따라 전체 남자 생활인구 대비 `남자0~9세 비율`의 변화를 한 눈에 알 수 있도록
# `남자0~9세 비율`을 선 그래프로 나타내주세요.
#
#
# * 한글 폰트가 깨지지 않도록 처리해주세요.
# * 그래프 사이즈는 20\*10으로 해주세요.

# %%
import matplotlib.pyplot as plt

plt.rc('font', family='malgun gothic')
plt.figure(figsize=(20,10))

#답변 작성
sample['남자0~9세 비율'].plot(kind='line'
                         ,title='남자0~9세 비율 추이'
                         ,xlabel='일자'
                         ,ylabel='비율')
# Out:
# <Axes: title={'center': '남자0~9세 비율 추이'}, xlabel='일자', ylabel='비율'>

# %%
남자_컬럼들 = [col for col in sample.columns if '남자' in col]
남자_컬럼들 = 남자_컬럼들[:-2]
남자_컬럼들
# Out:
# ['남자0~9세',
#  '남자10~14세',
#  '남자15~19세',
#  '남자20~24세',
#  '남자25~29세',
#  '남자30~34세',
#  '남자35~39세',
#  '남자40~44세',
#  '남자45~49세',
#  '남자50~54세',
#  '남자55~59세',
#  '남자60~64세',
#  '남자65~69세',
#  '남자70~74세',
#  '남자75~79세',
#  '남자80세이상']

# %%
sample.index[0].strftime("%Y-%m-%d")

# %%
# sample 데이터프레임에서 '남자_컬럼들'에 해당하는 컬럼만 선택하여 첫번째 행을 가져온 후, 
# pie chart로 시각화합니다.
# kind='pie' : pie chart로 시각화합니다.
# figsize=(10,10) : 그래프의 크기를 설정합니다.
# title='2020-01-01 남자 연령대별 비율' : 그래프의 제목을 설정합니다.
# autopct='%.2f%%' : 각 항목의 비율을 표시합니다. 소수점 둘째자리까지 표시합니다.
# fontsize=7 : 폰트 크기를 설정합니다.
# legend=True : 범례를 표시합니다.
# labels=남자_컬럼들 : 각 항목의 라벨을 설정합니다.
# labeldistance=1.1 : 라벨과 그래프의 중심점 사이의 거리를 설정합니다.
# startangle=90 : 그래프의 시작 각도를 설정합니다. 90도는 12시 방향입니다.

indexing = 0

sample[남자_컬럼들].iloc[indexing].plot(kind='pie'
                                    , figsize=(10,10)
                                    , title=sample.index[indexing].strftime("%Y-%m-%d")+' 남자 연령대별 비율'
                                    , autopct='%.2f%%'
                                    , fontsize=7
                                    , legend=True
                                    , labels=남자_컬럼들
                                    , labeldistance=1.1
                                    , startangle=90
                                    )
# Out:
# <Axes: title={'center': '2017-01-03 남자 연령대별 비율'}, ylabel='2017-01-03 00:00:00'>

# %%
sample[['행정동코드']].value_counts()
# Out:
# 행정동코드
# 11380690    5
# 11590605    5
# 11620735    5
# 11380560    5
# 11590660    5
#            ..
# 11410685    1
# 11410700    1
# 11410710    1
# 11440555    1
# 11740700    1
# Name: count, Length: 267, dtype: int64

# %%
value_counts == 5
# Out:
# 행정동코드
# 11410690     True
# 11230660     True
# 11380560     True
# 11380690     True
# 11590605     True
#             ...
# 11710632    False
# 11740640    False
# 11560650    False
# 11410700    False
# 11215847    False
# Name: count, Length: 267, dtype: bool

# %%
value_counts  = sample['행정동코드'].value_counts()

cond_value = value_counts[value_counts == 5].index.tolist()

condition = (sample['행정동코드'].isin(cond_value))

sample = sample.loc[condition]

# %%
#파일저장
sample.to_csv("내국인 생활인구_행정동코드_5개.csv", encoding="cp949")
